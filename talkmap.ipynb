# %% [markdown]
# # Leaflet cluster map of talk locations
#
# Run this from the _talks/ directory, which contains .md files of all your talks. This scrapes the location YAML field from each .md file, geolocates it with geopy/Nominatim, and uses the getorg library to output data, HTML, and Javascript for a standalone cluster map.

# %%
# !pip install getorg
# Out:
# Requirement already satisfied: getorg in /Users/saron/miniconda3/lib/python3.11/site-packages (0.3.1)
# Requirement already satisfied: geopy in /Users/saron/miniconda3/lib/python3.11/site-packages (from getorg) (2.4.1)
# Requirement already satisfied: pygithub in /Users/saron/miniconda3/lib/python3.11/site-packages (from getorg) (2.3.0)
# Requirement already satisfied: retrying in /Users/saron/miniconda3/lib/python3.11/site-packages (from getorg) (1.3.4)
# Requirement already satisfied: geographiclib<3,>=1.52 in /Users/saron/miniconda3/lib/python3.11/site-packages (from geopy->getorg) (2.0)
# Requirement already satisfied: pynacl>=1.4.0 in /Users/saron/miniconda3/lib/python3.11/site-packages (from pygithub->getorg) (1.5.0)
# Requirement already satisfied: requests>=2.14.0 in /Users/saron/miniconda3/lib/python3.11/site-packages (from pygithub->getorg) (2.31.0)
# Requirement already satisfied: pyjwt>=2.4.0 in /Users/saron/miniconda3/lib/python3.11/site-packages (from pyjwt[crypto]>=2.4.0->pygithub->getorg) (2.9.0)
# Requirement already satisfied: typing-extensions>=4.0.0 in /Users/saron/miniconda3/lib/python3.11/site-packages (from pygithub->getorg) (4.11.0)
# Requirement already satisfied: urllib3>=1.26.0 in /Users/saron/miniconda3/lib/python3.11/site-packages (from pygithub->getorg) (1.26.18)
# Requirement already satisfied: Deprecated in /Users/saron/miniconda3/lib/python3.11/site-packages (from pygithub->getorg) (1.2.14)
# Requirement already satisfied: six>=1.7.0 in /Users/saron/miniconda3/lib/python3.11/site-packages (from retrying->getorg) (1.16.0)
# Requirement already satisfied: cryptography>=3.4.0 in /Users/saron/miniconda3/lib/python3.11/site-packages (from pyjwt[crypto]>=2.4.0->pygithub->getorg) (41.0.7)
# Requirement already satisfied: cffi>=1.4.1 in /Users/saron/miniconda3/lib/python3.11/site-packages (from pynacl>=1.4.0->pygithub->getorg) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/saron/miniconda3/lib/python3.11/site-packages (from requests>=2.14.0->pygithub->getorg) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/saron/miniconda3/lib/python3.11/site-packages (from requests>=2.14.0->pygithub->getorg) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/saron/miniconda3/lib/python3.11/site-packages (from requests>=2.14.0->pygithub->getorg) (2023.11.17)
# Requirement already satisfied: wrapt<2,>=1.10 in /Users/saron/miniconda3/lib/python3.11/site-packages (from Deprecated->pygithub->getorg) (1.16.0)
# Requirement already satisfied: pycparser in /Users/saron/miniconda3/lib/python3.11/site-packages (from cffi>=1.4.1->pynacl>=1.4.0->pygithub->getorg) (2.21)

# %%
import sys
print(sys.executable)
# Out:
# /Applications/Xcode.app/Contents/Developer/usr/bin/python3

# %%
# !pip show getorg
# Out:
# Name: getorg
# Version: 0.3.1
# Summary: Information and analytics about GitHub organizations
# Home-page: http://github.com/getorg/getorg
# Author: Stuart Geiger
# Author-email: stuart@stuartgeiger.com
# License: MIT
# Location: /Users/saron/miniconda3/lib/python3.11/site-packages
# Requires: geopy, pygithub, retrying
# Required-by:

# %%
# !pip install getorg --upgrade
# import glob
import getorg
# from geopy import Nominatim
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[10], line 3
#       1 # !pip install getorg --upgrade
#       2 # import glob
# ----> 3 import getorg
#       4 # from geopy import Nominatim
#
# ModuleNotFoundError: No module named 'getorg'

# %%
g = glob.glob("*.md")

# %%
geocoder = Nominatim()
location_dict = {}
location = ""
permalink = ""
title = ""

# %%
for file in g:
    with open(file, 'r') as f:
        lines = f.read()
        if lines.find('location: "') > 1:
            loc_start = lines.find('location: "') + 11
            lines_trim = lines[loc_start:]
            loc_end = lines_trim.find('"')
            location = lines_trim[:loc_end]
                            
           
        location_dict[location] = geocoder.geocode(location)
        print(location, "\n", location_dict[location])
# Out:
# Berkeley CA, USA
#  Berkeley, Alameda County, California, United States of America
# Los Angeles, CA
#  LA, Los Angeles County, California, United States of America
# London, UK
#  London, Greater London, England, UK
# San Francisco, California
#  SF, California, United States of America

# %%
m = getorg.orgmap.create_map_obj()
getorg.orgmap.output_html_cluster_map(location_dict, folder_name="../talkmap", hashed_usernames=False)
# Out:
# 'Written map to ../talkmap/'
